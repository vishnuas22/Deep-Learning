# %%
! git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/darknet

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
#       |              ^~~~
# ...

# %%
# !cp /content/drive/MyDrive/dl_class/obj.zip ../

# %%
# !unzip  ../obj.zip -d data/
# Out:
# Archive:  ../obj.zip
#    creating: data/yolo/
#   inflating: data/yolo/car2.jpg
# replace data/__MACOSX/yolo/._car2.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: data/__MACOSX/yolo/._car2.jpg
#   inflating: data/yolo/car3.JPG
# replace data/__MACOSX/yolo/._car3.JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: data/__MACOSX/yolo/._car3.JPG
#   inflating: data/yolo/classes.txt
# replace data/__MACOSX/yolo/._classes.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: data/__MACOSX/yolo/._classes.txt
#   inflating: data/yolo/car1.jpg
# replace data/__MACOSX/yolo/._car1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: data/__MACOSX/yolo/._car1.jpg
#   inflating: data/yolo/car4.jpg
# replace data/__MACOSX/yolo/._car4.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: data/__MACOSX/yolo/._car4.jpg
#   inflating: data/yolo/.DS_Store
# replace data/__MACOSX/yolo/._.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# ...

# %%
# !cp /content/drive/MyDrive/dl_class/obj.names ./data

# %%
# !cp /content/drive/MyDrive/dl_class/yolov3_custom.cfg ./data

# %%
# !cp /content/drive/MyDrive/dl_class/obj.data ./data

# %%
# !cp /content/drive/MyDrive/dl_class/generate_train.py ./

# %%
# !ls ./data
# Out:
# 9k.tree     eagle.jpg	 imagenet.labels.list	   obj		     person.jpg  yolov3_custom.cfg
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  obj.data	     scream.jpg
# coco.names  goal.txt	 labels			   obj.names	     voc.names
# dog.jpg     horses.jpg	 __MACOSX		   openimages.names  yolo

# %%
pwd
# Out:
# '/content/darknet'

# %%
# !python generate_train.py

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2024-05-29 03:19:10--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.2’
#
# darknet53.conv.74.2 100%[===================>] 154.96M  13.3MB/s    in 11s
#
# 2024-05-29 03:19:23 (13.7 MB/s) - ‘darknet53.conv.74.2’ saved [162482580/162482580]

# %%
# !pwd
# Out:
# /content/darknet

# %%
# !./darknet detector train /content/darknet/data/obj.data /content/darknet/data/yolov3_custom.cfg /content/darknet/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000048, iou_loss = 0.000000, total_loss = 0.000048
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.838431), count: 1, class_loss = 0.000007, iou_loss = 0.018802, total_loss = 0.018809
#  total_bbox = 78107, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.809222), count: 1, class_loss = 0.000002, iou_loss = 0.016937, total_loss = 0.016940
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.897549), count: 3, class_loss = 0.007478, iou_loss = 0.022133, total_loss = 0.029611
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000007, iou_loss = 0.000000, total_loss = 0.000007
# ...
