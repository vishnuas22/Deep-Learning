# %%
# 1. Install dependencies (run once; skip if already installed)
# %pip install torch torchvision torchaudio --upgrade
# %pip install matplotlib opencv-python
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# %pip install -r requirements.txt

# 2. Import packages
import torch
from IPython.display import Image, display
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: torch in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (2.8.0)
# Requirement already satisfied: torchvision in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (0.23.0)
# Requirement already satisfied: torchaudio in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (2.8.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (3.9.2)
# Requirement already satisfied: opencv-python in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (4.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17581, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 17581 (delta 39), reused 9 (delta 9), pack-reused 17518 (from 4)
# Receiving objects: 100% (17581/17581), 16.69 MiB | 5.34 MiB/s, done.
# Resolving deltas: 100% (12039/12039), done.
# /Users/Dataghost/Master-X-DL/yolov5
# Collecting gitpython>=3.1.30 (from -r requirements.txt (line 5))
#   Using cached gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: matplotlib>=3.3 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (3.9.2)
# Requirement already satisfied: numpy>=1.23.5 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.1.1 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (4.11.0)
# Requirement already satisfied: pillow>=10.3.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (11.1.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (7.0.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (1.13.1)
# Collecting thop>=0.1.1 (from -r requirements.txt (line 14))
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.8.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (0.23.0)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (4.67.1)
# Collecting ultralytics>=8.2.64 (from -r requirements.txt (line 18))
#   Using cached ultralytics-8.3.202-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: pandas>=1.1.4 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (24.2)
# Requirement already satisfied: setuptools>=70.0.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (75.8.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->-r requirements.txt (line 5))
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (6.5.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2025.1.31)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.17.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.3)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2025.9.0)
# Requirement already satisfied: polars in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from ultralytics>=8.2.64->-r requirements.txt (line 18)) (1.33.1)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics>=8.2.64->-r requirements.txt (line 18))
#   Using cached ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3->-r requirements.txt (line 6)) (3.21.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/masterxdl/lib/python3.9/site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (3.0.2)
# Using cached gitpython-3.1.45-py3-none-any.whl (208 kB)
# Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Using cached ultralytics-8.3.202-py3-none-any.whl (1.1 MB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Installing collected packages: gitdb, gitpython, ultralytics-thop, thop, ultralytics
# Successfully installed gitdb-4.0.12 gitpython-3.1.45 thop-0.1.1.post2209072238 ultralytics-8.3.202 ultralytics-thop-2.0.17
# Note: you may need to restart the kernel to use updated packages.

# %%
# 2. Import packages
import torch
from IPython.display import Image, display
import matplotlib.pyplot as plt
